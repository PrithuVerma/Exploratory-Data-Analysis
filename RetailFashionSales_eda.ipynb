# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('/kaggle/input/retail-fashion-boutique-data-sales-analytics-2025/fashion_boutique_dataset.csv')
print(df.columns)
# Out:
# Index(['product_id', 'category', 'brand', 'season', 'size', 'color',
#        'original_price', 'markdown_percentage', 'current_price',
#        'purchase_date', 'stock_quantity', 'customer_rating', 'is_returned',
#        'return_reason'],
#       dtype='object')

# %% [markdown]
# # **Handling Missing and Duplicate values**

# %%
average_rating = df.customer_rating.mean().round()
df['customer_rating'] = df['customer_rating'].fillna(average_rating)
df.customer_rating.isnull().sum()
df['product_id'].drop_duplicates()
df.head()
# Out:
#   product_id     category            brand  season size  color  \
# 0   FB000001    Outerwear             Zara  Spring   XL    Red
# 1   FB000002         Tops           Uniqlo  Winter    L   Pink
# 2   FB000003  Accessories           Uniqlo  Winter  NaN  Black
# 3   FB000004        Shoes           Uniqlo  Spring   XL  Black
# 4   FB000005         Tops  Banana Republic  Winter   XL  Black
#
#    original_price  markdown_percentage  current_price purchase_date  \
# 0          196.01                  0.0         196.01    2025-07-05
# 1          119.64                  0.0         119.64    2025-08-06
# 2           33.80                  0.0          33.80    2025-08-06
# 3           75.36                  0.0          75.36    2025-07-07
# 4          105.02                  0.0         105.02    2025-08-06
#
#    stock_quantity  customer_rating  is_returned return_reason
# 0              37              3.0        False           NaN
# 1               2              2.5        False           NaN
# 2              22              4.3        False           NaN
# 3              48              2.6        False           NaN
# 4              10              3.0        False           NaN

# %% [markdown]
# # **Performing EDA**

# %%
md_percentages = df.markdown_percentage.unique()
max_md_percentage = df.markdown_percentage.max()
min_md_percentage = df.markdown_percentage.min()

print(f'Max %:{max_md_percentage}\nMin% :{min_md_percentage}')
md_percentages.size
# Out:
# Max %:59.9
# Min% :0.0
# 458

# %%
og_price_null_vals = df.original_price.isnull().sum()
avg_og_price = df.original_price.mean().round(3)

print(f'Null values : {og_price_null_vals}\nAverage Price : {avg_og_price}')
# Out:
# Null values : 0
# Average Price : 97.2

# %%
brands = df.brand.unique()
df['size'] = df['size'].fillna('Unkown')

brand_by_color = df.pivot_table(index='brand', columns='color', aggfunc='size', fill_value=0)
brand_by_color
# Out:
# color            Beige  Black  Blue  Brown  Gray  Green  Navy  Pink  Purple  \
# brand
# Ann Taylor          30     27    15     14    28     22    27    22      20
# Banana Republic     17     22    30     31    27     33    26    15      28
# Forever21           17     24    22     22    15     28    24    30      17
# Gap                 17     31    23     18    25     22    26    17      22
# H&M                 25     30    27     21    19     30    30    23      23
# Mango               19     29    23     27    14     31    24    42      25
# Uniqlo              22     27    25     19    29     26    17    28      23
# Zara                29     26    26     28    32     30    18    27      29
#
# color            Red  White
# brand
# Ann Taylor        19     33
# Banana Republic   28     28
# Forever21         26     25
# Gap               24     19
# H&M               26     29
# Mango             26     24
# Uniqlo            25     19
# Zara              38     30

# %% [markdown]
# # **Pie Chart of different Brands by Color**

# %%
# for brand in brands:
#     brand_data = df[df['brand'] == brand]['color'].value_counts()
#     plt.figure(figsize=(6,6))
#     plt.pie(brand_data, labels=brand_data.index, autopct='%1.1f%%', startangle=90)
#     plt.title(f"Color distribution for {brand}")
#     plt.show()

# %%
df.head()
# Out:
#   product_id     category            brand  season    size  color  \
# 0   FB000001    Outerwear             Zara  Spring      XL    Red
# 1   FB000002         Tops           Uniqlo  Winter       L   Pink
# 2   FB000003  Accessories           Uniqlo  Winter  Unkown  Black
# 3   FB000004        Shoes           Uniqlo  Spring      XL  Black
# 4   FB000005         Tops  Banana Republic  Winter      XL  Black
#
#    original_price  markdown_percentage  current_price purchase_date  \
# 0          196.01                  0.0         196.01    2025-07-05
# 1          119.64                  0.0         119.64    2025-08-06
# 2           33.80                  0.0          33.80    2025-08-06
# 3           75.36                  0.0          75.36    2025-07-07
# 4          105.02                  0.0         105.02    2025-08-06
#
#    stock_quantity  customer_rating  is_returned return_reason
# 0              37              3.0        False           NaN
# 1               2              2.5        False           NaN
# 2              22              4.3        False           NaN
# 3              48              2.6        False           NaN
# 4              10              3.0        False           NaN

# %%
df.return_reason.unique()
df['return_reason'] = df['return_reason'].fillna('Other')
df.return_reason.unique()
# Out:
# array(['Other', 'Color Mismatch', 'Size Issue', 'Damaged',
#        'Quality Issue', 'Changed Mind', 'Wrong Item'], dtype=object)

# %%
df['purchase_date'] = pd.to_datetime(df['purchase_date'])

df['purchase_month'] = df['purchase_date'].dt.month_name()
df['purchase_year'] = df['purchase_date'].dt.year

df.drop('purchase_date',axis = 1,inplace = True)
df.head()
# Out:
#   product_id     category            brand  season    size  color  \
# 0   FB000001    Outerwear             Zara  Spring      XL    Red
# 1   FB000002         Tops           Uniqlo  Winter       L   Pink
# 2   FB000003  Accessories           Uniqlo  Winter  Unkown  Black
# 3   FB000004        Shoes           Uniqlo  Spring      XL  Black
# 4   FB000005         Tops  Banana Republic  Winter      XL  Black
#
#    original_price  markdown_percentage  current_price  stock_quantity  \
# 0          196.01                  0.0         196.01              37
# 1          119.64                  0.0         119.64               2
# 2           33.80                  0.0          33.80              22
# 3           75.36                  0.0          75.36              48
# 4          105.02                  0.0         105.02              10
#
#    customer_rating  is_returned return_reason purchase_month  purchase_year
# 0              3.0        False         Other           July           2025
# 1              2.5        False         Other         August           2025
# 2              4.3        False         Other         August           2025
# 3              2.6        False         Other           July           2025
# 4              3.0        False         Other         August           2025

# %%
# Out:
# array([False,  True])
